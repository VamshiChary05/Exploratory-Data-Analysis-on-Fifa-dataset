# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x= pd.read_csv('C:/Users/Pooja/EDA module/EDA _Mini Project/fifa.csv')

# %%
x.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
d1 = pd.read_csv('C:/Users/Pooja/EDA module/EDA _Mini Project/fifa_ variable_information.csv')
d1.head()
# Out:
#             ID     unique id for every player
# 0         Name                           name
# 1          Age                            age
# 2        Photo      url to the player's photo
# 3  Nationality                    nationality
# 4         Flag  url to players's country flag

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
x.isnull().sum()/len(x)*100
# Out:
# ID                           0.000000
# Name                         0.000000
# Age                          0.000000
# Photo                        0.000000
# Nationality                  0.000000
# Flag                         0.000000
# Overall                      0.000000
# Potential                    0.000000
# Club                         1.323667
# Club Logo                    0.000000
# Value                        0.000000
# Wage                         0.000000
# Preferred Foot               0.263635
# International Reputation     0.263635
# Weak Foot                    0.263635
# Skill Moves                  0.263635
# Work Rate                    0.263635
# Body Type                    0.263635
# Position                     0.329544
# Jersey Number                0.329544
# Joined                       8.529686
# Loaned From                 93.057615
# Contract Valid Until         1.587302
# Height                       0.263635
# Weight                       0.263635
# ...

# %%
d

# %%
x.drop(["ID","Composure","Marking","StandingTackle","SlidingTackle","Photo","Flag","Club Logo",'Composure','Marking','StandingTackle','SlidingTackle','GKDiving','GKHandling','GKKicking','GKPositioning','GKReflexes'],axis=1,inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  object
#  7   Wage                      18207 non-null  object
#  8   Preferred Foot            18159 non-null  object
#  9   International Reputation  18159 non-null  float64
#  10  Weak Foot                 18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Work Rate                 18159 non-null  object
# ...

# %%
x.drop('Loaned From',axis=1,inplace=True)

# %%
x
# Out:
#                      Name  Age Nationality  Overall  Potential  \
# 0                L. Messi   31   Argentina       94         94
# 1       Cristiano Ronaldo   33    Portugal       94         94
# 2               Neymar Jr   26      Brazil       92         93
# 3                  De Gea   27       Spain       91         93
# 4            K. De Bruyne   27     Belgium       91         92
# ...                   ...  ...         ...      ...        ...
# 18202        J. Lundstram   19     England       47         65
# 18203  N. Christoffersson   19      Sweden       47         63
# 18204           B. Worman   16     England       47         67
# 18205      D. Walker-Rice   17     England       47         66
# 18206           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  \
# 0             FC Barcelona  €110.5M  €565K           Left
# 1                 Juventus     €77M  €405K          Right
# ...

# %%
x['Wage'] = x['Wage'].apply(lambda x:x.replace('€',''))
x['Wage'] = x['Wage'].apply(lambda x:x.replace('K',''))
x['Wage'] = x['Wage'].apply(lambda x:x.strip())

# %%
x['Value'] = x['Value'].apply(lambda x:x.replace('€',''))
x['Value'] = x['Value'].apply(lambda x:x.replace('M',' '))
x['Value'] = x['Value'].apply(lambda x:x.strip())
x['Value'] = x['Value'].apply(lambda x:x.replace('K',''))

# %%
x['Wage']=x['Wage'].astype(float)

# %%
x['Value']=x['Value'].astype(float)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  float64
#  7   Wage                      18207 non-null  float64
#  8   Preferred Foot            18159 non-null  object
#  9   International Reputation  18159 non-null  float64
#  10  Weak Foot                 18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Work Rate                 18159 non-null  object
# ...

# %%
x.drop(['Jumping','Stamina','LongShots','Interceptions','Positioning','Vision','Penalties','FKAccuracy','LongPassing','BallControl','Acceleration','SprintSpeed','Agility','Reactions','Balance','ShotPower','HeadingAccuracy','ShortPassing','Volleys','Dribbling','Curve'],axis=1,inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  float64
#  7   Wage                      18207 non-null  float64
#  8   Preferred Foot            18159 non-null  object
#  9   International Reputation  18159 non-null  float64
#  10  Weak Foot                 18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Work Rate                 18159 non-null  object
# ...

# %%
x.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club  Value   Wage Preferred Foot  International Reputation  \
# 0         FC Barcelona  110.5  565.0           Left                       5.0
# 1             Juventus   77.0  405.0          Right                       5.0
# 2  Paris Saint-Germain  118.5  290.0          Right                       5.0
# 3    Manchester United   72.0  260.0          Right                       4.0
# 4      Manchester City  102.0  355.0          Right                       4.0
#
#    ...  Jersey Number        Joined Contract Valid Until Height  Weight  \
# ...

# %%
x.drop(['Preferred Foot','Jersey Number','Crossing'],axis=1,inplace=True)

# %%
x.drop(['Body Type',"Skill Moves","Weak Foot"],axis=1,inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  float64
#  7   Wage                      18207 non-null  float64
#  8   International Reputation  18159 non-null  float64
#  9   Work Rate                 18159 non-null  object
#  10  Position                  18147 non-null  object
#  11  Joined                    16654 non-null  object
#  12  Contract Valid Until      17918 non-null  object
# ...

# %%
x['Joined']
# Out:
# 0         Jul 1, 2004
# 1        Jul 10, 2018
# 2         Aug 3, 2017
# 3         Jul 1, 2011
# 4        Aug 30, 2015
#              ...
# 18202     May 3, 2017
# 18203    Mar 19, 2018
# 18204     Jul 1, 2017
# 18205    Apr 24, 2018
# 18206    Oct 30, 2018
# Name: Joined, Length: 18207, dtype: object

# %%
x['Joined'] = pd.to_datetime(x['Joined'],format = '%b %d, %Y').dt.year
x['Joined'] = x['Joined'].astype(int)
x['Joined']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-6d78077830d1> in <module>
#       1 x['Joined'] = pd.to_datetime(x['Joined'],format = '%b %d, %Y').dt.year
# ----> 2 x['Joined'] = x['Joined'].astype(int)
#       3 x['Joined']
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
x['Joined']
# Out:
# 0        2004.0
# 1        2018.0
# 2        2017.0
# 3        2011.0
# 4        2015.0
#           ...
# 18202    2017.0
# 18203    2018.0
# 18204    2017.0
# 18205    2018.0
# 18206    2018.0
# Name: Joined, Length: 18207, dtype: float64

# %%
x['Contract Valid Until'].unique()
# Out:
# array(['2021', '2022', '2020', '2023', '2019', '2024', 'Jun 30, 2019',
#        '2025', '2026', 'Dec 31, 2018', '2018', nan, 'May 31, 2020',
#        'Jun 30, 2020', 'May 31, 2019', 'Dec 31, 2019', 'Jan 1, 2019',
#        'Jun 1, 2019', 'Jan 4, 2019', 'Jan 31, 2019', 'Jan 7, 2019',
#        'Jan 2, 2019', 'Jan 6, 2019', 'Oct 14, 2019', 'Jan 3, 2019',
#        'May 4, 2019', 'Jan 12, 2019', 'Jan 25, 2019', 'Jan 18, 2019',
#        'Dec 1, 2019', 'Nov 30, 2018', 'Feb 27, 2020', 'Jan 5, 2019',
#        'Jan 15, 2019', 'Jan 30, 2019', 'Jan 11, 2019', 'Jan 20, 2019'],
#       dtype=object)

# %%
x['Contract Valid Until'] = pd.to_datetime(x['Contract Valid Until'])

# %%
x['Contract Valid Until'].unique()
# Out:
# array(['2021-01-01T00:00:00.000000000', '2022-01-01T00:00:00.000000000',
#        '2020-01-01T00:00:00.000000000', '2023-01-01T00:00:00.000000000',
#        '2019-01-01T00:00:00.000000000', '2024-01-01T00:00:00.000000000',
#        '2019-06-30T00:00:00.000000000', '2025-01-01T00:00:00.000000000',
#        '2026-01-01T00:00:00.000000000', '2018-12-31T00:00:00.000000000',
#        '2018-01-01T00:00:00.000000000',                           'NaT',
#        '2020-05-31T00:00:00.000000000', '2020-06-30T00:00:00.000000000',
#        '2019-05-31T00:00:00.000000000', '2019-12-31T00:00:00.000000000',
#        '2019-06-01T00:00:00.000000000', '2019-01-04T00:00:00.000000000',
#        '2019-01-31T00:00:00.000000000', '2019-01-07T00:00:00.000000000',
#        '2019-01-02T00:00:00.000000000', '2019-01-06T00:00:00.000000000',
#        '2019-10-14T00:00:00.000000000', '2019-01-03T00:00:00.000000000',
#        '2019-05-04T00:00:00.000000000', '2019-01-12T00:00:00.000000000',
# ...

# %%
x['Height'].unique()
# Out:
# array(["5'7", "6'2", "5'9", "6'4", "5'11", "5'8", "6'0", "5'6", "5'10",
#        "6'6", "6'1", "5'4", "6'3", "5'5", "6'5", "6'7", "5'3", "5'2",
#        "6'8", "5'1", "6'9", nan], dtype=object)

# %%
x['Height'].isnull().sum()
# Out:
# 48

# %%
x['Height'].isnull().sum()/len(d1)*100
# Out:
# 81.35593220338984

# %%
x.dropna(subset=['Height'],inplace=True)

# %%
x['Height'] = x['Height'].apply(lambda x:x.replace("'",'.'))

# %%
x['Height'] = pd.to_numeric(x['Height'])

# %%
x['Height'].unique()
# Out:
# array([5.7 , 6.2 , 5.9 , 6.4 , 5.11, 5.8 , 6.  , 5.6 , 5.1 , 6.6 , 6.1 ,
#        5.4 , 6.3 , 5.5 , 6.5 , 6.7 , 5.3 , 5.2 , 6.8 , 6.9 ])

# %%
x['Weight'] = x['Weight'].apply(lambda x: x.replace('lbs',' '))

# %%
x['Weight']
# Out:
# 0        159
# 1        183
# 2        150
# 3        168
# 4        154
#          ...
# 18202    134
# 18203    170
# 18204    148
# 18205    154
# 18206    176
# Name: Weight, Length: 18159, dtype: object

# %%
x['Weight'] = pd.to_numeric(x['Weight'])

# %%
x['Release Clause'].unique()
# Out:
# array(['€226.5M', '€127.1M', '€228.1M', ..., '€74K', '€101K', '€147K'],
#       dtype=object)

# %%
x['Release Clause'].isnull().sum()/len(x)*100
# Out:
# 8.348477339060521

# %%
x.dropna(subset=['Release Clause'],inplace=True)

# %%
x['Release Clause'].isnull().sum()
# Out:
# 0

# %%
x['Release Clause'] = x['Release Clause'].apply(lambda x: x.replace('€',''))
x['Release Clause'] = x['Release Clause'].apply(lambda x: x.replace('M',''))
x['Release Clause'] = x['Release Clause'].apply(lambda x: x.replace('K',''))

# %%
x['Release Clause'] = x['Release Clause'].astype(float)

# %%
x['Release Clause'].unique()
# Out:
# array([226.5, 127.1, 228.1, ...,  67. , 101. , 147. ])

# %%
a = x.isnull().sum()
a[a!=0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# #exploratory data analysis

# %%
#1.Plot the distribution of Overall rating for all players.

# %%
x['Work Rate']
# Out:
# 0        Medium/ Medium
# 1             High/ Low
# 2          High/ Medium
# 3        Medium/ Medium
# 4            High/ High
#               ...
# 18202    Medium/ Medium
# 18203    Medium/ Medium
# 18204    Medium/ Medium
# 18205    Medium/ Medium
# 18206    Medium/ Medium
# Name: Work Rate, Length: 16643, dtype: object

# %%
x.groupby(['Work Rate','Name'])['Overall'].mean()
# Out:
# Work Rate       Name
# High/ High      A. Abrashi             71.0
#                 A. Ademi               74.0
#                 A. Andrianarimanana    63.0
#                 A. Androutsos          68.0
#                 A. Balzano             69.0
#                                        ...
# Medium/ Medium  Íñigo López            66.0
#                 Óliver Torres          78.0
#                 Óscar Gil              59.0
#                 Óscar Valentín         65.0
#                 Óscar Whalley          65.0
# Name: Overall, Length: 16321, dtype: float64

# %%
sns.kdeplot(x['Overall'])
plt.show()

# %%
#2.	Generate pair plots for the following variables:
#Overall, Value, Wage, International Reputation, Height, Weight, Release Clause

# %%
sns.pairplot(data=x,vars=['Overall','Wage','International Reputation','Height','Weight','Release Clause'])
plt.show()

# %%
#3.Generate a table containing the top 20 players ranked by Overall score and whose contract expires in 2020.
#a)What would the average wage for this set of players be?
#b)What is the average age?
#c)Is there a correlation between the Overall rating and Value for these players?

# %%
x[(x['Overall']) & (x['Contract Valid Until'] == '2020')].head(20)
# Out:
#              Name  Age         Nationality  Overall  Potential  \
# 3          De Gea   27               Spain       91         93
# 5       E. Hazard   27             Belgium       91         91
# 6       L. Modrić   32             Croatia       91         91
# 8    Sergio Ramos   32               Spain       91         91
# 21      E. Cavani   31             Uruguay       89         89
# 24   G. Chiellini   33               Italy       89         89
# 46       K. Navas   31          Costa Rica       87         87
# 49     Jordi Alba   29               Spain       87         87
# 50     D. Mertens   31             Belgium       87         87
# 52      M. Hamšík   30            Slovakia       87         87
# 80       N. Fekir   24              France       85         89
# 90         Parejo   29               Spain       85         85
# 98       E. Džeko   32  Bosnia Herzegovina       85         85
# 102         Naldo   35              Brazil       85         85
# ...

# %%
x[(x['Overall']) & (x['Contract Valid Until'] == '2020')].head(20).groupby('Wage').mean()
# Out:
#         Age  Overall  Potential  Value  International Reputation  Joined  \
# Wage
# 38.0   35.0     85.0       85.0   9.00                       3.0  2016.0
# 66.0   29.0     85.0       85.0  37.00                       2.0  2011.0
# 67.0   27.0     83.0       86.0  26.00                       2.0  2015.0
# 70.0   27.5     83.0       85.0  23.75                       3.0  2014.0
# 85.0   22.0     83.0       88.0  34.50                       2.0  2017.0
# 92.0   24.0     85.0       89.0  50.00                       3.0  2013.0
# 96.0   33.0     85.0       85.0  15.50                       3.0  2017.0
# 115.0  32.0     85.0       85.0  30.50                       3.0  2015.0
# 125.0  30.0     87.0       87.0  46.50                       3.0  2007.0
# 135.0  31.0     87.0       87.0  45.00                       3.0  2013.0
# 145.0  31.0     85.0       85.0  26.00                       3.0  2017.0
# 195.0  31.0     87.0       87.0  30.50                       3.0  2014.0
# ...

# %%
x[(x['Overall']) & (x['Contract Valid Until'] == '2020')].head(20).groupby('Age').mean()
# Out:
#        Overall  Potential      Value        Wage  International Reputation  \
# Age
# 22   83.000000  87.500000  34.500000   77.500000                  2.500000
# 24   85.000000  89.000000  50.000000   92.000000                  3.000000
# 27   88.333333  90.000000  63.666667  222.333333                  3.333333
# 29   86.000000  86.000000  37.500000  158.000000                  2.500000
# 30   87.000000  87.000000  46.500000  125.000000                  3.000000
# 31   87.000000  87.000000  40.375000  168.750000                  3.250000
# 32   89.000000  89.000000  49.500000  305.000000                  3.666667
# 33   85.666667  85.666667  18.500000  127.000000                  3.333333
# 35   85.000000  85.000000   9.000000   38.000000                  3.000000
#
#           Joined    Height      Weight  Finishing   Strength  Aggression  \
# Age
# 22   2016.500000  5.505000  165.000000  84.000000  63.500000   63.000000
# ...

# %%
d2 = x[(x['Overall']) & (x['Contract Valid Until'] == '2020')].head(20)
d2[['Overall','Value']].corr()
# Out:
#           Overall     Value
# Overall  1.000000  0.751775
# Value    0.751775  1.000000

# %%
#4.Generate tables containing the top 5 players by Overall rating for each unique position.
#a)Are there any players appearing in more than one Table. Please point out such players.
#b)What is the average wage one can expect to pay for the top 5 in every position?

# %%
x['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LM', 'LB', 'RDM', 'RW',
#        'CM', 'RB', 'RAM', 'CF', 'LAM', 'RWB', 'LWB'], dtype=object)

# %%
#Top five for RF Position
df1 = x[(x['Overall']) & (x['Position'] == 'RF')].head()
df1
# Out:
#                     Name  Age Nationality  Overall  Potential            Club  \
# 50            D. Mertens   31     Belgium       87         87          Napoli
# 1774            C. Ciano   28       Italy       75         75       Frosinone
# 6108           H. Yamada   29       Japan       69         69    Júbilo Iwata
# 6161  D. Moberg Karlsson   24      Sweden       69         75  IFK Norrköping
# 6430          P. Forsell   27     Finland       69         69   Miedź Legnica
#
#       Value   Wage  International Reputation     Work Rate Position  Joined  \
# 50     45.0  135.0                       3.0     High/ Low       RF  2013.0
# 1774    6.5   17.0                       1.0  High/ Medium       RF  2017.0
# 6108    1.0    4.0                       1.0  High/ Medium       RF  2017.0
# 6161    1.5    4.0                       1.0  High/ Medium       RF  2016.0
# 6430    1.1    3.0                       1.0      Low/ Low       RF  2018.0
#
# ...

# %%
# Top five for ST Position
df2 = x[(x['Overall']) & (x['Position'] == 'ST')].head()
df2
# Out:
#            Name  Age Nationality  Overall  Potential               Club  \
# 16      H. Kane   24     England       89         91  Tottenham Hotspur
# 23    S. Agüero   30   Argentina       89         89    Manchester City
# 43    M. Icardi   25   Argentina       87         90              Inter
# 47    R. Lukaku   25     Belgium       87         89  Manchester United
# 48  C. Immobile   28       Italy       87         87              Lazio
#
#     Value   Wage  International Reputation       Work Rate Position  Joined  \
# 16   83.5  205.0                       3.0      High/ High       ST  2010.0
# 23   64.5  300.0                       4.0    High/ Medium       ST  2011.0
# 43   64.5  130.0                       3.0     Medium/ Low       ST  2013.0
# 47   62.5  230.0                       3.0  Medium/ Medium       ST  2017.0
# 48   52.0  115.0                       3.0    High/ Medium       ST  2016.0
#
#    Contract Valid Until  Height  Weight  Finishing  Strength  Aggression  \
# ...

# %%
#Top 5 for LW Position
df3 = x[(x['Overall']) & (x['Position'] == 'LW')].head()
df3
# Out:
#             Name  Age  Nationality  Overall  Potential  \
# 319  M. Rashford   20      England       81         89
# 334     Williams   24        Spain       81         87
# 347      A. Plea   25       France       81         83
# 384   D. Perotti   29    Argentina       81         81
# 575  S. Bergwijn   20  Netherlands       79         86
#
#                          Club  Value   Wage  International Reputation  \
# 319         Manchester United   27.0  110.0                       2.0
# 334   Athletic Club de Bilbao   24.5   31.0                       2.0
# 347  Borussia Mönchengladbach   22.0   40.0                       2.0
# 384                      Roma   17.5   84.0                       3.0
# 575                       PSV   18.0   17.0                       1.0
#
#           Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# 319    High/ Medium       LW  2014.0           2020-01-01    6.10     154
# ...

# %%
# Top five for GK Position
df4 = x[(x['Overall']) & (x['Position'] == 'GK')].head()
df4
# Out:
#              Name  Age Nationality  Overall  Potential               Club  \
# 3          De Gea   27       Spain       91         93  Manchester United
# 18  M. ter Stegen   26     Germany       89         92       FC Barcelona
# 19    T. Courtois   26     Belgium       89         90        Real Madrid
# 22       M. Neuer   32     Germany       89         89  FC Bayern München
# 46       K. Navas   31  Costa Rica       87         87        Real Madrid
#
#     Value   Wage  International Reputation       Work Rate Position  Joined  \
# 3    72.0  260.0                       4.0  Medium/ Medium       GK  2011.0
# 18   58.0  240.0                       3.0  Medium/ Medium       GK  2014.0
# 19   53.5  240.0                       4.0  Medium/ Medium       GK  2018.0
# 22   38.0  130.0                       5.0  Medium/ Medium       GK  2011.0
# 46   30.5  195.0                       3.0  Medium/ Medium       GK  2014.0
#
# ...

# %%
#Top five for RCM position
df5 = x[(x['Overall']) & (x['Position'] == 'RCM')].head()
df5
# Out:
#             Name  Age Nationality  Overall  Potential               Club  \
# 4   K. De Bruyne   27     Belgium       91         92    Manchester City
# 6      L. Modrić   32     Croatia       91         91        Real Madrid
# 53    I. Rakitić   30     Croatia       87         87       FC Barcelona
# 82    J. Kimmich   23     Germany       85         88  FC Bayern München
# 83          Saúl   23       Spain       85         90    Atlético Madrid
#
#     Value   Wage  International Reputation   Work Rate Position  Joined  \
# 4   102.0  355.0                       4.0  High/ High      RCM  2015.0
# 6    67.0  420.0                       4.0  High/ High      RCM  2012.0
# 53   46.5  260.0                       4.0  High/ High      RCM  2014.0
# 82   40.5   92.0                       3.0   High/ Low      RCM  2015.0
# 83   50.5   77.0                       3.0  High/ High      RCM  2013.0
#
#    Contract Valid Until  Height  Weight  Finishing  Strength  Aggression  \
# ...

# %%
#Top five for LF Position
df6 = x[(x['Overall']) & (x['Position'] == 'LF')].head()
df6
# Out:
#                Name  Age    Nationality  Overall  Potential  \
# 5         E. Hazard   27        Belgium       91         91
# 15        P. Dybala   24      Argentina       89         94
# 2608      S. Araujo   26      Argentina       73         76
# 4592       P. Ebert   31        Germany       71         71
# 5855  A. Trajkovski   25  FYR Macedonia       69         72
#
#                    Club  Value   Wage  International Reputation     Work Rate  \
# 5               Chelsea   93.0  340.0                       4.0  High/ Medium
# 15             Juventus   89.0  205.0                       3.0  High/ Medium
# 2608      UD Las Palmas    5.0   11.0                       1.0   Medium/ Low
# 4592  SG Dynamo Dresden    2.1   13.0                       1.0  Medium/ High
# 5855            Palermo    1.3    3.0                       1.0      Low/ Low
#
#      Position  Joined Contract Valid Until  Height  Weight  Finishing  \
# ...

# %%
#Top five for RS Position
df7 = x[(x['Overall']) & (x['Position'] == 'RS')].head()
df7
# Out:
#                  Name  Age Nationality  Overall  Potential          Club  \
# 7           L. Suárez   31     Uruguay       91         91  FC Barcelona
# 109    Z. Ibrahimović   36      Sweden       85         85     LA Galaxy
# 403   F. Quagliarella   35       Italy       81         81     Sampdoria
# 589  A. Saint-Maximin   21      France       79         86      OGC Nice
# 608             Roger   27       Spain       79         80    Levante UD
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 7     80.0  455.0                       5.0    High/ Medium       RS  2014.0
# 109   14.0   15.0                       5.0     Medium/ Low       RS  2018.0
# 403    8.0   39.0                       2.0  Medium/ Medium       RS  2016.0
# 589   18.0   31.0                       2.0       High/ Low       RS  2017.0
# 608   14.5   32.0                       2.0    High/ Medium       RS  2011.0
#
# ...

# %%
# Top five for RCB position
df8 = x[(x['Overall']) & (x['Position'] == 'RCB')].head()
df8
# Out:
#              Name  Age Nationality  Overall  Potential               Club  \
# 8    Sergio Ramos   32       Spain       91         91        Real Madrid
# 54          Piqué   31       Spain       87         87       FC Barcelona
# 95     J. Boateng   29     Germany       85         85  FC Bayern München
# 108          Pepe   35    Portugal       85         85        Beşiktaş JK
# 175        Felipe   29      Brazil       83         83           FC Porto
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 8     51.0  380.0                       4.0    High/ Medium      RCB  2005.0
# 54    34.0  240.0                       4.0    High/ Medium      RCB  2008.0
# 95    30.0  115.0                       4.0  Medium/ Medium      RCB  2011.0
# 108    9.0   57.0                       4.0    Medium/ High      RCB  2017.0
# 175   20.0   22.0                       3.0    Medium/ High      RCB  2016.0
#
# ...

# %%
 'LCM', 'CB','LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LM', 'LB', 'RDM', 'RW',
       'CM', 'RB', 'RAM', 'CF', 'LAM', 'RWB', 'LWB'

# %%
#Top five for LCM Position 
df9 = x[(x['Overall']) & (x['Position'] == 'LCM')].head()
df9
# Out:
#               Name  Age Nationality  Overall  Potential              Club  \
# 52       M. Hamšík   30    Slovakia       87         87            Napoli
# 194          Pizzi   28    Portugal       83         83        SL Benfica
# 195       K. Kampl   27    Slovenia       83         83        RB Leipzig
# 205          Oscar   26      Brazil       83         84  Shanghai SIPG FC
# 328  Dani Ceballos   21       Spain       81         88       Real Madrid
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 52    46.5  125.0                       3.0    High/ Medium      LCM  2007.0
# 194   25.5   22.0                       3.0    High/ Medium      LCM  2013.0
# 195   26.5   74.0                       2.0      High/ High      LCM  2017.0
# 205   30.5   29.0                       3.0  Medium/ Medium      LCM  2017.0
# 328   25.0  120.0                       1.0  Medium/ Medium      LCM  2017.0
#
# ...

# %%
#Top five for CB Position 
df10 = x[(x['Overall']) & (x['Position'] == 'CB')].head()
df10
# Out:
#             Name  Age Nationality  Overall  Potential             Club  Value  \
# 42     S. Umtiti   24      France       87         92     FC Barcelona   57.0
# 89   N. Otamendi   30   Argentina       85         85  Manchester City   28.5
# 102        Naldo   35      Brazil       85         85    FC Schalke 04    9.0
# 104      Miranda   33      Brazil       85         85            Inter   15.5
# 107   V. Kompany   32     Belgium       85         85  Manchester City   22.0
#
#       Wage  International Reputation       Work Rate Position  Joined  \
# 42   205.0                       3.0    Medium/ High       CB  2016.0
# 89   170.0                       3.0      High/ High       CB  2015.0
# 102   38.0                       3.0  Medium/ Medium       CB  2016.0
# 104   96.0                       3.0    Medium/ High       CB  2017.0
# 107  170.0                       4.0    Medium/ High       CB  2008.0
#
# ...

# %%
#Top five for LDM Position 
df11 = x[(x['Overall']) & (x['Position'] == 'LDM')].head()
df11
# Out:
#             Name  Age  Nationality  Overall  Potential     Club  Value   Wage  \
# 14      N. Kanté   27       France       89         90  Chelsea   63.0  225.0
# 217  Lucas Leiva   31       Brazil       83         83    Lazio   17.5   64.0
# 323   F. de Jong   21  Netherlands       81         89     Ajax   26.0   19.0
# 331      J. Seri   26  Ivory Coast       81         82   Fulham   20.5   73.0
# 333  M. Brozović   25      Croatia       81         84    Inter   18.5   64.0
#
#      International Reputation       Work Rate Position  Joined  \
# 14                        3.0    Medium/ High      LDM  2016.0
# 217                       3.0    Medium/ High      LDM  2017.0
# 323                       1.0  Medium/ Medium      LDM  2015.0
# 331                       2.0  Medium/ Medium      LDM  2018.0
# 333                       2.0  Medium/ Medium      LDM  2016.0
#
#     Contract Valid Until  Height  Weight  Finishing  Strength  Aggression  \
# ...

# %%
#Top five for CAM Position 
df12 = x[(x['Overall']) & (x['Position'] == 'CAM')].head()
df12
# Out:
#               Name  Age Nationality  Overall  Potential                Club  \
# 17    A. Griezmann   27      France       89         90     Atlético Madrid
# 80        N. Fekir   24      France       85         89  Olympique Lyonnais
# 96        A. Vidal   31       Chile       85         85        FC Barcelona
# 101  R. Nainggolan   30     Belgium       85         85               Inter
# 208       Giuliano   28      Brazil       83         83            Al Nassr
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 17    78.0  145.0                       4.0      High/ High      CAM  2014.0
# 80    50.0   92.0                       3.0    High/ Medium      CAM  2013.0
# 96    26.0  205.0                       4.0  Medium/ Medium      CAM  2018.0
# 101   35.5  105.0                       3.0      High/ High      CAM  2018.0
# 208   26.0   64.0                       2.0    High/ Medium      CAM  2018.0
#
# ...

# %%
#Top five for CDM Position 
df13 = x[(x['Overall']) & (x['Position'] == 'CDM')].head()
df13
# Out:
#                 Name  Age  Nationality  Overall  Potential  \
# 20   Sergio Busquets   29        Spain       89         89
# 187   Danilo Pereira   26     Portugal       83         86
# 203     K. Strootman   28  Netherlands       83         83
# 215    Javi Martínez   29        Spain       83         83
# 353        C. Kramer   27      Germany       81         82
#
#                          Club  Value   Wage  International Reputation  \
# 20               FC Barcelona   51.5  315.0                       4.0
# 187                  FC Porto   27.0   21.0                       3.0
# 203    Olympique de Marseille   21.0   66.0                       3.0
# 215         FC Bayern München   20.0   94.0                       3.0
# 353  Borussia Mönchengladbach   17.0   35.0                       2.0
#
#           Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# 20   Medium/ Medium      CDM  2008.0           2023-01-01     6.2     168
# ...

# %%
#Top five for LS Position 
df14 = x[(x['Overall']) & (x['Position'] == 'LS')].head()
df14
# Out:
#               Name  Age Nationality  Overall  Potential                 Club  \
# 21       E. Cavani   31     Uruguay       89         89  Paris Saint-Germain
# 100    Diego Costa   29       Spain       85         85      Atlético Madrid
# 174  Gerard Moreno   26       Spain       83         85        Villarreal CF
# 206   M. Balotelli   27       Italy       83         83             OGC Nice
# 329      H. Lozano   22      Mexico       81         86                  PSV
#
#      Value   Wage  International Reputation     Work Rate Position  Joined  \
# 21    60.0  200.0                       4.0    High/ High       LS  2013.0
# 100   38.5  100.0                       4.0  High/ Medium       LS  2018.0
# 174   32.0   53.0                       1.0  High/ Medium       LS  2018.0
# 206   27.5   55.0                       4.0   Medium/ Low       LS  2016.0
# 329   24.0   22.0                       3.0  High/ Medium       LS  2017.0
#
# ...

# %%
#Top five for LCB Position 
df15 = x[(x['Overall']) & (x['Position'] == 'LCB')].head()
df15
# Out:
#              Name  Age Nationality  Overall  Potential               Club  \
# 24   G. Chiellini   33       Italy       89         89           Juventus
# 44   K. Koulibaly   27     Senegal       87         90             Napoli
# 51  J. Vertonghen   31     Belgium       87         87  Tottenham Hotspur
# 77    M. Škriniar   23    Slovakia       85         92              Inter
# 88     K. Manolas   27      Greece       85         87               Roma
#
#     Value   Wage  International Reputation     Work Rate Position  Joined  \
# 24   27.0  215.0                       4.0  Medium/ High      LCB  2005.0
# 44   51.0  115.0                       3.0    High/ High      LCB  2014.0
# 51   34.0  155.0                       3.0    High/ High      LCB  2012.0
# 77   46.5   82.0                       1.0  Medium/ High      LCB  2017.0
# 88   37.5   96.0                       3.0     Low/ High      LCB  2014.0
#
#    Contract Valid Until  Height  Weight  Finishing  Strength  Aggression  \
# ...

# %%
#Top five for RM Position 
df16 = x[(x['Overall']) & (x['Position'] == 'RM')].head()
df16
# Out:
#               Name  Age  Nationality  Overall  Potential               Club  \
# 170      Q. Promes   26  Netherlands       83         84         Sevilla FC
# 186    Lucas Moura   25       Brazil       83         84  Tottenham Hotspur
# 199  H. Mkhitaryan   29      Armenia       83         83            Arsenal
# 211      Juan Mata   30        Spain       83         83  Manchester United
# 335      A. Correa   23    Argentina       81         87    Atlético Madrid
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 170   30.5   28.0                       2.0       High/ Low       RM  2018.0
# 186   31.0  115.0                       3.0    High/ Medium       RM  2018.0
# 199   25.5  145.0                       3.0  Medium/ Medium       RM  2018.0
# 211   24.5  160.0                       3.0  Medium/ Medium       RM  2014.0
# 335   24.5   54.0                       1.0     Medium/ Low       RM  2014.0
#
# ...

# %%
#Top five for LM Position 
df17 = x[(x['Overall']) & (x['Position'] == 'LM')].head()
df17
# Out:
#            Name  Age Nationality  Overall  Potential             Club  Value  \
# 86         Koke   26       Spain       85         86  Atlético Madrid   45.0
# 94   Y. Brahimi   28     Algeria       85         85         FC Porto   39.0
# 97   I. Perišić   29     Croatia       85         85            Inter   37.5
# 103  B. Matuidi   31      France       85         85         Juventus   26.0
# 163    T. Lemar   22      France       83         89  Atlético Madrid   35.5
#
#       Wage  International Reputation       Work Rate Position  Joined  \
# 86    88.0                       3.0      High/ High       LM  2011.0
# 94    28.0                       3.0    High/ Medium       LM  2014.0
# 97   110.0                       3.0  Medium/ Medium       LM  2015.0
# 103  145.0                       3.0      High/ High       LM  2017.0
# 163   64.0                       3.0    High/ Medium       LM  2018.0
#
#     Contract Valid Until  Height  Weight  Finishing  Strength  Aggression  \
# ...

# %%
#Top five for LB Position 
df18 = x[(x['Overall']) & (x['Position'] == 'LB')].head()
df18
# Out:
#               Name  Age Nationality  Overall  Potential               Club  \
# 49      Jordi Alba   29       Spain       87         87       FC Barcelona
# 85        D. Alaba   26     Austria       85         87  FC Bayern München
# 106    Filipe Luís   32      Brazil       85         85    Atlético Madrid
# 200  Marcos Alonso   27       Spain       83         84            Chelsea
# 342       Grimaldo   22       Spain       81         87         SL Benfica
#
#      Value   Wage  International Reputation     Work Rate Position  Joined  \
# 49    38.0  250.0                       3.0  High/ Medium       LB  2012.0
# 85    38.0  110.0                       4.0  High/ Medium       LB  2010.0
# 106   21.5   81.0                       3.0  High/ Medium       LB  2015.0
# 200   24.0  130.0                       2.0     High/ Low       LB  2016.0
# 342   20.5   14.0                       3.0  High/ Medium       LB  2016.0
#
# ...

# %%
'RDM', 'RW',
       'CM', 'RB', 'RAM', 'CF', 'LAM', 'RWB', 'LWB']

# %%
#Top five for RDM Position 
df19 = x[(x['Overall']) & (x['Position'] == 'RDM')].head()
df19
# Out:
#             Name  Age Nationality  Overall  Potential                Club  \
# 45      P. Pogba   25      France       87         91   Manchester United
# 198     I. Gueye   28     Senegal       83         83             Everton
# 223  D. De Rossi   34       Italy       83         83                Roma
# 344  A. Doucouré   25      France       81         85             Watford
# 572   L. Tousart   21      France       79         84  Olympique Lyonnais
#
#      Value   Wage  International Reputation     Work Rate Position  Joined  \
# 45    64.0  210.0                       4.0     High/ Low      RDM  2016.0
# 198   21.0  125.0                       2.0  Medium/ High      RDM  2016.0
# 223    8.0   80.0                       3.0  Medium/ High      RDM  2002.0
# 344   19.5   60.0                       2.0  High/ Medium      RDM  2016.0
# 572   14.5   43.0                       2.0  Medium/ High      RDM  2015.0
#
# ...

# %%
#Top five for RM Position 
df20 = x[(x['Overall']) & (x['Position'] == 'RM')].head()
df20
# Out:
#               Name  Age  Nationality  Overall  Potential               Club  \
# 170      Q. Promes   26  Netherlands       83         84         Sevilla FC
# 186    Lucas Moura   25       Brazil       83         84  Tottenham Hotspur
# 199  H. Mkhitaryan   29      Armenia       83         83            Arsenal
# 211      Juan Mata   30        Spain       83         83  Manchester United
# 335      A. Correa   23    Argentina       81         87    Atlético Madrid
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 170   30.5   28.0                       2.0       High/ Low       RM  2018.0
# 186   31.0  115.0                       3.0    High/ Medium       RM  2018.0
# 199   25.5  145.0                       3.0  Medium/ Medium       RM  2018.0
# 211   24.5  160.0                       3.0  Medium/ Medium       RM  2014.0
# 335   24.5   54.0                       1.0     Medium/ Low       RM  2014.0
#
# ...

# %%
#Top five for CM Position 
df21 = x[(x['Overall']) & (x['Position'] == 'CM')].head()
df21
# Out:
#                     Name  Age Nationality  Overall  Potential  \
# 78   S. Milinković-Savić   23      Serbia       85         90
# 161             N. Keïta   23      Guinea       83         88
# 162           C. Tolisso   23      France       83         88
# 168            A. Rabiot   23      France       83         87
# 169          L. Goretzka   23     Germany       83         88
#
#                     Club  Value   Wage  International Reputation  \
# 78                 Lazio   50.5   73.0                       2.0
# 161            Liverpool   34.0  120.0                       2.0
# 162    FC Bayern München   34.0   85.0                       2.0
# 168  Paris Saint-Germain   33.0   91.0                       2.0
# 169    FC Bayern München   34.0   85.0                       3.0
#
#         Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# 78   High/ Medium       CM  2015.0           2023-01-01    6.30     168
# ...

# %%
#Top five for RB Position 
df22 = x[(x['Overall']) & (x['Position'] == 'RB')].head()
df22
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 192    Sergi Roberto   26       Spain       83         86
# 216        L. Bender   29     Germany       83         83
# 324    Nélson Semedo   24    Portugal       81         86
# 339         E. Hysaj   24     Albania       81         86
# 341  Ricardo Pereira   24    Portugal       81         85
#
#                     Club  Value   Wage  International Reputation  \
# 192         FC Barcelona   26.5  170.0                       3.0
# 216  Bayer 04 Leverkusen   20.0   82.0                       3.0
# 324         FC Barcelona   20.0  125.0                       2.0
# 339               Napoli   20.0   58.0                       2.0
# 341       Leicester City   19.0   64.0                       3.0
#
#           Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# 192      High/ High       RB  2013.0           2022-01-01     5.1     150
# ...

# %%
#Top five for RAM Position 
df23 = x[(x['Overall']) & (x['Position'] == 'RAM')].head()
df23
# Out:
#                    Name  Age Nationality  Overall  Potential  \
# 171           H. Ziyech   25     Morocco       83         86
# 1705     Allan Bardinho   26      Brazil       75         75
# 2927  Gustavo Lobateiro   30      Brazil       73         73
# 4160     Tiago Pombeira   30      Brazil       71         71
# 4193          L. Seijas   32   Venezuela       71         71
#
#                         Club  Value  Wage  International Reputation  \
# 171                     Ajax   32.5  28.0                       3.0
# 1705                Botafogo    7.0  22.0                       1.0
# 2927           Internacional    3.8  21.0                       1.0
# 4160        Atlético Mineiro    2.2  21.0                       1.0
# 4193  Independiente Santa Fe    1.8   3.0                       1.0
#
#            Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# 171       High/ High      RAM  2016.0           2021-01-01    5.11     143
# ...

# %%
#Top five for CF Position 
df24 = x[(x['Overall']) & (x['Position'] == 'CF')].head()
df24
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 350          A. Milik   24      Poland       81         88
# 382         L. Stindl   29     Germany       81         81
# 407           Raffael   33      Brazil       81         81
# 663   Ricardo Goulart   27      Brazil       79         80
# 1691       S. Okazaki   32       Japan       75         75
#
#                                 Club  Value  Wage  International Reputation  \
# 350                           Napoli   25.5  71.0                       3.0
# 382         Borussia Mönchengladbach   18.0  43.0                       2.0
# 407         Borussia Mönchengladbach   11.0  41.0                       2.0
# 663   Guangzhou Evergrande Taobao FC   14.5  25.0                       2.0
# 1691                  Leicester City    5.5  59.0                       2.0
#
#            Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# ...

# %%
#Top five for LAM Position 
df26 = x[(x['Overall']) & (x['Position'] == 'LAM')].head()
df26
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 365         D. Tadić   29      Serbia       81         81
# 1587  Fabrio Farinha   26      Brazil       75         75
# 4241   Paulolettinho   34      Brazil       71         71
# 4353   Heltinho Melo   34      Brazil       71         71
# 4407   Marlion Rolim   26      Brazil       71         71
#
#                      Club  Value  Wage  International Reputation  \
# 365                  Ajax   17.5  26.0                       3.0
# 1587     Atlético Mineiro    7.0  31.0                       1.0
# 4241               Paraná    1.2  14.0                       1.0
# 4353  Atlético Paranaense    1.2  10.0                       1.0
# 4407             Cruzeiro    2.5  18.0                       1.0
#
#            Work Rate Position  Joined Contract Valid Until  Height  Weight  \
# 365      Medium/ Low      LAM  2018.0           2022-01-01    5.11     168
# ...

# %%
#Top five for RWB Position 
df27 = x[(x['Overall']) & (x['Position'] == 'RWB')].head()
df27
# Out:
#               Name  Age Nationality  Overall  Potential                  Club  \
# 652   D. Caligiuri   30       Italy       79         79         FC Schalke 04
# 976        K. Lala   26      France       77         78  RC Strasbourg Alsace
# 1025    R. Aguilar   25      France       77         81       Montpellier HSC
# 1663       E. Durm   26     Germany       75         77     Huddersfield Town
# 1670      M. Risse   28     Germany       75         75            1. FC Köln
#
#       Value  Wage  International Reputation       Work Rate Position  Joined  \
# 652     9.0  33.0                       2.0  Medium/ Medium      RWB  2017.0
# 976     8.5  19.0                       1.0    High/ Medium      RWB  2017.0
# 1025    9.5  23.0                       1.0      High/ High      RWB  2017.0
# 1663    6.5  38.0                       2.0    High/ Medium      RWB  2018.0
# 1670    6.5  21.0                       2.0    Medium/ High      RWB  2013.0
#
# ...

# %%
#Top five for LWB Position 
df27 = x[(x['Overall']) & (x['Position'] == 'LWB')].head()
df27
# Out:
#              Name  Age          Nationality  Overall  Potential  \
# 581       Granell   29                Spain       79         79
# 605     J. Hector   28              Germany       79         79
# 1080     R. Brady   26  Republic of Ireland       77         78
# 1148   B. Oczipka   29              Germany       77         77
# 1690  L. Vangioni   31            Argentina       75         75
#
#                Club  Value  Wage  International Reputation       Work Rate  \
# 581       Girona FC   12.0  37.0                       1.0  Medium/ Medium
# 605      1. FC Köln   10.0  26.0                       3.0  Medium/ Medium
# 1080        Burnley   10.5  52.0                       1.0    High/ Medium
# 1148  FC Schalke 04    6.5  30.0                       2.0    High/ Medium
# 1690      Monterrey    4.4  37.0                       1.0      High/ High
#
#      Position  Joined Contract Valid Until  Height  Weight  Finishing  \
# ...

# %%
top_five = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,
                     df22,df23,df24,df26,df27])
top_five
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 50            D. Mertens   31              Belgium       87         87
# 1774            C. Ciano   28                Italy       75         75
# 6108           H. Yamada   29                Japan       69         69
# 6161  D. Moberg Karlsson   24               Sweden       69         75
# 6430          P. Forsell   27              Finland       69         69
# ...                  ...  ...                  ...      ...        ...
# 581              Granell   29                Spain       79         79
# 605            J. Hector   28              Germany       79         79
# 1080            R. Brady   26  Republic of Ireland       77         78
# 1148          B. Oczipka   29              Germany       77         77
# 1690         L. Vangioni   31            Argentina       75         75
#
#                 Club  Value   Wage  International Reputation       Work Rate  \
# ...

# %%
#a) Are there any players appearing in more than one Table. Please point out such players.
top_five[top_five.duplicated()]
# Out:
#               Name  Age  Nationality  Overall  Potential               Club  \
# 170      Q. Promes   26  Netherlands       83         84         Sevilla FC
# 186    Lucas Moura   25       Brazil       83         84  Tottenham Hotspur
# 199  H. Mkhitaryan   29      Armenia       83         83            Arsenal
# 211      Juan Mata   30        Spain       83         83  Manchester United
# 335      A. Correa   23    Argentina       81         87    Atlético Madrid
#
#      Value   Wage  International Reputation       Work Rate Position  Joined  \
# 170   30.5   28.0                       2.0       High/ Low       RM  2018.0
# 186   31.0  115.0                       3.0    High/ Medium       RM  2018.0
# 199   25.5  145.0                       3.0  Medium/ Medium       RM  2018.0
# 211   24.5  160.0                       3.0  Medium/ Medium       RM  2014.0
# 335   24.5   54.0                       1.0     Medium/ Low       RM  2014.0
#
# ...

# %%
#b) What is the average wage one can expect to pay for the top 5 in every position?

# %%
top_five.groupby('Position')['Wage'].mean()
# Out:
# Position
# CAM    122.2
# CB     135.8
# CDM    106.2
# CF      47.8
# CM      90.8
# GK     213.0
# LAM     19.8
# LB     117.0
# LCB    132.6
# LCM     74.0
# LDM     89.0
# LF     114.4
# LM      87.0
# LS      86.0
# LW      56.4
# LWB     36.4
# RAM     19.0
# RB      99.8
# RCB    162.8
# RCM    240.8
# RDM    103.6
# RF      32.6
# RM     100.4
# RS     114.4
# ST     196.0
# Name: Wage, dtype: float64
